# %% [markdown]
# <a href="https://colab.research.google.com/github/jamieprince/jamieprince.github.io/blob/main/BB_Index_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd
url='https://raw.githubusercontent.com/jamieprince/jamieprince.github.io/main/bloomberg_billionaire_index.html'
from bs4 import BeautifulSoup
html = requests.get(url)
soup = BeautifulSoup(html.content, 'html.parser')

# %%
soup.findAll('div')
table=soup.find_all("div",class_="table-cell t-name")
for i in soup.find_all('div', class_="table-cell t-name"):
    print(i.a)
name_list= [i.text for i in table]
name_list = [item.replace("\r\n                            ", "").replace(",", "") for item in name_list]
name_list
# Out:
# <a href="./profiles/elon-r-musk/">
#                             Elon Musk</a>
# <a href="./profiles/jeffrey-p-bezos/">
#                             Jeff Bezos</a>
# <a href="./profiles/bernard-arnault/">
#                             Bernard Arnault</a>
# <a href="./profiles/william-h-gates/">
#                             Bill Gates</a>
# <a href="./profiles/lawrence-e-page/">
#                             Larry Page</a>
# <a href="./profiles/mark-e-zuckerberg/">
#                             Mark Zuckerberg</a>
# <a href="./profiles/sergey-brin/">
#                             Sergey Brin</a>
# <a href="./profiles/steve-ballmer/">
#                             Steve Ballmer</a>
# <a href="./profiles/lawrence-j-ellison/">
#                             Larry Ellison</a>
# <a href="./profiles/warren-e-buffett/">
#                             Warren Buffett</a>
# <a href="./profiles/francoise-bettencourt-meyers/">
#                             Francoise Bettencourt Meyers</a>
# ...

# %%
table=soup.find_all("div",class_="table-cell active t-nw")
for i in soup.find_all('div', class_="table-cell active t-nw"):
    print(i.a)
networth_list= [i.text for i in table]
networth_list= [item2.replace("\r\n                        ", "").replace("\r\n                    ", "").replace("$","").replace("B","") for item2 in networth_list]
del networth_list[0]
import numpy as np
list(np.float_(networth_list))
networth_list
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
table=soup.find_all("div",class_="table-cell t-country")
for i in soup.find_all('div', class_="table-cell t-country"):
    print(i.a)
country_list= [i.text for i in table]
country_list = [item3.replace("\r\n                        ", "").replace("\r\n                    ", "") for item3 in country_list]
del country_list[0]
country_list
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
table=soup.find_all("div",class_="table-cell t-industry")
for i in soup.find_all('div', class_="table-cell t-industry"):
    print(i.a)
industry_list = [i.text for i in table]
industry_list = [item4.replace("\r\n                        ", "").replace("\r\n                    ", "") for item4 in industry_list]
del industry_list[0]
industry_list
# Out:
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
df1=pd.DataFrame([name_list,networth_list,country_list,industry_list]).T

# %%
df1.columns=['Name','Total net worth','Country / Region','Industry']

# %%
pd.concat([df1])
# Out:
#                 Name Total net worth Country / Region    Industry
# 0          Elon Musk             311    United States  Technology
# 1         Jeff Bezos             210    United States  Technology
# 2    Bernard Arnault             174           France    Consumer
# 3         Bill Gates             139    United States  Technology
# 4         Larry Page             132    United States  Technology
# ..               ...             ...              ...         ...
# 495     Wang Wenjing            5.99            China  Technology
# 496           Su Hua            5.99            China  Technology
# 497       Mark Cuban            5.98    United States  Technology
# 498     Finn Rausing            5.98           Sweden    Services
# 499  Kirsten Rausing            5.98           Sweden    Services
#
# [500 rows x 4 columns]

# %%
df1.to_csv('Bloomberg_Billionaires_Index.csv')
