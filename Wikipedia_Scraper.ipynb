# %% [markdown]
# <a href="https://colab.research.google.com/github/jamieprince/jamieprince.github.io/blob/main/Wikipedia_Scraper.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests, pandas as pd

# %%
tables=pd.read_html('https://en.wikipedia.org/wiki/The_World%27s_Billionaires')

# %%
tables[37]
# Out:
#                                 Year  ...        Group's combined net worth
# 0                            2021[2]  ...                    $13.1 trillion
# 1                               2020  ...                     $8.0 trillion
# 2                               2019  ...                     $8.7 trillion
# 3                               2018  ...                     $9.1 trillion
# 4                               2017  ...                     $7.7 trillion
# 5                               2016  ...                     $6.5 trillion
# 6                           2015[15]  ...                     $7.1 trillion
# 7                           2014[61]  ...                     $6.4 trillion
# 8                           2013[62]  ...                     $5.4 trillion
# 9                               2012  ...                     $4.6 trillion
# 10                              2011  ...                     $4.5 trillion
# ...

# %%
df=tables[37]

# %%
df.columns=['Year','Number of Billionaires','Total Net Worth (Trillion)']

# %%
df['Total Net Worth (Trillion)']=df['Total Net Worth (Trillion)'].str.replace('$','').str.replace('trillion','')

# %%
df
# Out:
#                                 Year  ...        Total Net Worth (Trillion)
# 0                            2021[2]  ...                             13.1
# 1                               2020  ...                              8.0
# 2                               2019  ...                              8.7
# 3                               2018  ...                              9.1
# 4                               2017  ...                              7.7
# 5                               2016  ...                              6.5
# 6                           2015[15]  ...                              7.1
# 7                           2014[61]  ...                              6.4
# 8                           2013[62]  ...                              5.4
# 9                               2012  ...                              4.6
# 10                              2011  ...                              4.5
# ...

# %%
df.to_csv('no_billionaires_per_year.csv')
